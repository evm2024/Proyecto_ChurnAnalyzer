# %%
# Carga del dataset
import pandas as pd
df = pd.read_csv("C:/Users/paula/Analitica de Big Data/Churn Analyzer/Data/Telco_customer_churn_limpio.csv")

# Eliminar columnas irrelevantes
cols_drop = ["CustomerID","Churn_Label","City","State",
    "Zip Code","Latitude","Longitude","CLTV",
    "Gender","Phone_Service","Multiple_Lines"]

df = df.drop(columns = cols_drop, errors = "ignore")

#Visulización del dataset con las columnas eliminadas
df.head(10)
# Out:
#   Senior_Citizen Partner Dependents  Tenure_Months Internet_Service  \
# 0             No      No         No              2              DSL
# 1             No      No        Yes              2      Fiber optic
# 2             No      No        Yes              8      Fiber optic
# 3             No     Yes        Yes             28      Fiber optic
# 4             No      No        Yes             49      Fiber optic
# 5             No     Yes         No             10              DSL
# 6            Yes      No         No              1              DSL
# 7             No      No         No              1               No
# 8             No     Yes        Yes             47      Fiber optic
# 9             No     Yes         No              1              DSL
#
#        Online_Security        Online_Backup    Device_Protection  \
# 0                  Yes                  Yes                   No
# 1                   No                   No                   No
# 2                   No                   No                  Yes
# 3                   No                   No                  Yes
# 4                   No                  Yes                  Yes
# 5                   No                   No                  Yes
# 6                   No                   No                  Yes
# 7  No internet service  No internet service  No internet service
# 8                   No                  Yes                   No
# 9                   No                  Yes                   No
#
#           Tech_Support         Streaming_TV     Streaming_Movies  \
# 0                   No                   No                   No
# 1                   No                   No                   No
# 2                   No                  Yes                  Yes
# 3                  Yes                  Yes                  Yes
# 4                   No                  Yes                  Yes
# 5                  Yes                   No                   No
# 6                   No                   No                  Yes
# 7  No internet service  No internet service  No internet service
# 8                   No                  Yes                  Yes
# 9                   No                   No                   No
#
#          Contract Paperless_Billing             Payment_Method  \
# 0  Month-to-month               Yes               Mailed check
# 1  Month-to-month               Yes           Electronic check
# 2  Month-to-month               Yes           Electronic check
# 3  Month-to-month               Yes           Electronic check
# 4  Month-to-month               Yes  Bank transfer (automatic)
# 5  Month-to-month                No    Credit card (automatic)
# 6  Month-to-month               Yes           Electronic check
# 7  Month-to-month                No               Mailed check
# 8  Month-to-month               Yes           Electronic check
# 9  Month-to-month                No           Electronic check
#
#    Monthly_Charges  Total_Charges  Churn_Value  Churn_Score
# 0            53.85         108.15            1           86
# 1            70.70         151.65            1           67
# 2            99.65         820.50            1           86
# 3           104.80        3046.05            1           84
# 4           103.70        5036.30            1           89
# 5            55.20         528.35            1           78
# 6            39.65          39.65            1          100
# 7            20.15          20.15            1           92
# 8            99.35        4749.15            1           77
# 9            30.20          30.20            1           97

# %%
# Selección de variable objetivo.
y = df["Churn_Value"]
X = df.drop(columns = ["Churn_Value"])

X = pd.get_dummies(X, drop_first = True)

# %%
# Train/Test split (70/30)
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

# %%
# Entrenamiento del modelo.
